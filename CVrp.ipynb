# %%
#importing 
import pandas as pd
import os
import csv
import matplotlib.pyplot as plt

# %%
#reading CSV
corona_virus = pd.read_csv("2019_nCoV_data.csv")
corona_virus
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
# ...

# %%
without_china = corona_virus.loc[corona_virus["Country"] !="Mainland China"]
countries_cv = without_china.groupby("Country").sum()
countries_updated = countries_cv[['Deaths']]

# %%
countries_updated.plot(kind="bar", figsize=(10,5))
plt.title("Deaths by Country Excluding China")
plt.show()
plt.tight_layout()

# %%
countries_updated.plot.pie(y='Deaths', figsize=(15, 15))
plt.title("Deaths by Province/State")
plt.show()
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %%
corona_deaths = corona_virus.groupby("Country").sum()
corona_deaths
# Out:
#                          Sno  Confirmed   Deaths  Recovered
# Country
# Australia              80718      284.0      0.0       70.0
# Belgium                17149       14.0      0.0        1.0
# Brazil                    83        0.0      0.0        0.0
# Cambodia               20871       22.0      0.0        6.0
# Canada                 59273      116.0      0.0        6.0
# China                    598      549.0      0.0        0.0
# Egypt                   6378        4.0      0.0        0.0
# Finland                20353       20.0      0.0        7.0
# France                 21044      186.0      3.0       18.0
# Germany                20542      252.0      0.0        5.0
# Hong Kong              20834      681.0     14.0        8.0
# India                  19768       50.0      0.0        6.0
# Italy                  19787       49.0      0.0        0.0
# Ivory Coast              264        0.0      0.0        0.0
# ...

# %%
country_deaths_filtered = corona_deaths[['Deaths']]
country_deaths_filtered
# Out:
#                        Deaths
# Country
# Australia                 0.0
# Belgium                   0.0
# Brazil                    0.0
# Cambodia                  0.0
# Canada                    0.0
# China                     0.0
# Egypt                     0.0
# Finland                   0.0
# France                    3.0
# Germany                   0.0
# Hong Kong                14.0
# India                     0.0
# Italy                     0.0
# Ivory Coast               0.0
# Japan                     5.0
# Macau                     0.0
# Mainland China        17908.0
# Malaysia                  0.0
# Mexico                    0.0
# Nepal                     0.0
# Others                    0.0
# Philippines              17.0
# Russia                    0.0
# Singapore                 0.0
# South Korea               0.0
# Spain                     0.0
# Sri Lanka                 0.0
# Sweden                    0.0
# Taiwan                    2.0
# ...

# %%
country_deaths.plot.pie(y='Deaths', figsize=(15, 15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-73669f07b7b7> in <module>
# ----> 1 country_deaths.plot.pie(y='Deaths', figsize=(15, 15))
#
# NameError: name 'country_deaths' is not defined

# %%
#Starting Country Analysis
#Dataframe without Hubei
without_hubei = corona_virus.loc[corona_virus["Province/State"] !="Hubei"]
without_hubei.head()
# Out:
#    Sno                 Date Province/State Country          Last Update  \
# 0    1  01/22/2020 12:00:00          Anhui   China  01/22/2020 12:00:00
# 1    2  01/22/2020 12:00:00        Beijing   China  01/22/2020 12:00:00
# 2    3  01/22/2020 12:00:00      Chongqing   China  01/22/2020 12:00:00
# 3    4  01/22/2020 12:00:00         Fujian   China  01/22/2020 12:00:00
# 4    5  01/22/2020 12:00:00          Gansu   China  01/22/2020 12:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
#grouping by Province/State
country_cv = without_hubei.groupby("Province/State").sum()
#Showing deaths per province/state
country_cv["Deaths"]
#Showing deaths per province/state > 0
deaths = country_cv[country_cv["Deaths"]>0]
only_deaths = deaths[['Deaths']]
only_deaths
# Out:
#                 Deaths
# Province/State
# Anhui             46.0
# Beijing           42.0
# Chongqing         50.0
# Fujian             1.0
# Gansu             19.0
# Guangdong         19.0
# Guangxi           16.0
# Guizhou           13.0
# Hainan            48.0
# Hebei             42.0
# Heilongjiang     117.0
# Henan            126.0
# Hong Kong         14.0
# Hunan             19.0
# Jiangxi            9.0
# Jilin             11.0
# Liaoning           6.0
# Shandong          17.0
# Shanghai          24.0
# Sichuan           24.0
# Taiwan             2.0
# Tianjin           25.0
# Xinjiang           6.0

# %%
#plotting bar graph

only_deaths.plot(kind="bar", figsize=(10,5))
plt.title("Deaths by Province/State")
plt.show()
plt.tight_layout()

# %%
#plotting pie chart

only_deaths.plot.pie(y='Deaths', figsize=(15, 15))
plt.title("Deaths by Province/State")
plt.show()
plt.tight_layout()

# %%
#starting time analysis
#grouping by date

date_cv = corona_virus.groupby("Date").sum()

#Taking serial no. out
no_sno = date_cv[['Confirmed','Recovered','Deaths']]
no_sno
# Out:
#                      Confirmed  Recovered  Deaths
# Date
# 01/22/2020 12:00:00      555.0        0.0     0.0
# 01/23/2020 12:00:00      653.0       30.0    18.0
# 01/24/2020 12:00:00      941.0       36.0    26.0
# 01/25/2020 22:00:00     2019.0       49.0    56.0
# 01/26/2020 23:00:00     2794.0       54.0    80.0
# 01/27/2020 20:30:00     4473.0       63.0   107.0
# 01/28/2020 23:00:00     6057.0      110.0   132.0
# 01/29/2020 21:00:00     7783.0      133.0   170.0
# 01/30/2020 21:30:00     9776.0      187.0   213.0
# 01/31/2020 19:00:00    11374.0      252.0   259.0
# 02/01/2020 23:00:00    14549.0      340.0   305.0
# 02/02/2020 21:00:00    17295.0      487.0   362.0
# 02/03/2020 21:40:00    20588.0      644.0   426.0
# 02/04/2020 22:00:00    24503.0      899.0   492.0
# 02/05/2020 12:20:00    24630.0     1029.0   494.0
# 02/06/2020 20:05:00    30806.0     1487.0   634.0
# 02/07/2020 20:24:00    31532.0     1763.0   638.0
# 02/08/2020 23:04:00    37549.0     2701.0   813.0
# ...

# %%
# Out:
#           Sno  Confirmed   Deaths  Recovered
# Date
# True  1478340   781452.0  17949.0    76258.0

# %%
#Plotting Line Chart

plt.figure(figsize=(20,10))
no_sno.plot()
plt.title("Confirmed vs. Recovered vs. Deaths")
plt.xlabel("Date")
plt.ylabel("Number of Cases")
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Plotting Second Line Chart Without Confirmed Cases

no_confirmed = date_cv[['Recovered','Deaths']]
no_confirmed
no_confirmed.plot()
plt.title("Recovered vs. Deaths")
plt.xlabel("Date")
plt.ylabel("Number of Cases")
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Plotting Third Line Chart Without Recovered Cases

no_recovered = date_cv[['Deaths']]
no_recovered
no_recovered.plot()
plt.title("Deaths")
plt.xlabel("Date")
plt.ylabel("Number of Cases")
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
